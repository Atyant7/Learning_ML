# %%
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

#load dataset
data = pd.read_csv("student_data_5000.csv")

#input & output
x = data[['Study_Hour_Per_Week']]
y = data[['Final_score']]

#train model
model = LinearRegression()
model.fit(x,y)
predicted_score = model.predict(x)

#Value regression tricks
mae = mean_absolute_error(y , predicted_score)
mse = mean_squared_error(y , predicted_score)
rmse = np.sqrt(mse)
r2 = r2_score(y, predicted_score)

#show results
print("Mean Absolute Error:",round(mae , 2))
print("Mean Squared Error:" , round(mse , 2))
print("Root Mean Squared Error:", round(rmse , 2))
print("R^2 Score (Model Accuracy):", round(r2 , 4)) #Closer to on then its better.


#histogram
#bins -> how many bar you want
plt.figure(figsize= (10 , 6))
plt.hist(y, bins= 30, color='skyblue' , edgecolor='black')
plt.title("Distribution of final exam scores")
plt.xlabel("Final exam score")
plt.ylabel("No. of students")
plt.grid(True)
plt.show()

#Scatter + Regression line
plt.figure(figsize= (10 , 6))
plt.scatter(x,y, color='blue' ,label="Actual_scores")
plt.plot(x,predicted_score, color="red", label="Predicted Scores (Regression Line)")
plt.title("Model Prediction vs Aactual Score")
plt.xlabel("Study Hours per week")
plt.ylabel("Final Output")
plt.grid(True)
plt.show()

new_hours = 9
predicted_new_score = model.predict([[new_hours]])
print(f"Predicted Final score for {new_hours} Hours is {predicted_new_score} Score.")
# Out:
# Mean Absolute Error: 5.23
# Mean Squared Error: 36.48
# Root Mean Squared Error: 6.04
# R^2 Score (Model Accuracy): 0.0001
# Predicted Final score for 9 Hours is [[40.04354064]] Score.
# C:\Users\Atyan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
